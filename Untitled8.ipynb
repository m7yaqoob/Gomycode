# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv (r"C:\Users\Mohamed\Downloads\titanic-passengers.csv", sep=";")
df.head()
df.info 
#df['Age'].fillna(df['Age'].mean(), inplace = True)
#df["Cabin"].fillna('G6',inplace=True)
df["Embarked"].fillna('S',inplace=True)
X= pd.isnull(df).sum()
print(df["Cabin"].value_counts())
print(df["Embarked"].value_counts())
print(X)

ax = sns.violinplot(x="Age", y="Age", data=df,)
# Out:
# B96 B98        4
# C23 C25 C27    4
# G6             4
# F33            3
# E101           3
#               ..
# B86            1
# C104           1
# C86            1
# C99            1
# D11            1
# Name: Cabin, Length: 147, dtype: int64
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df["Embarked"])
df["Embarked"] = le.transform(df["Embarked"])
df['Embarked_c'] = le.transform(df["Embarked"])
df.head()
# Out:
# C:\Users\Mohamed\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:579: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7f4f2989694a> in <module>
#       3 le.fit(df["Embarked"])
#       4 df["Embarked"] = le.transform(df["Embarked"])
# ----> 5 df['Embarked_c'] = le.transform(df["Embarked"])
#       6 df.head()
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in transform(self, y)
#     136             return np.array([])
#     137
# --> 138         return _encode(y, uniques=self.classes_)
#     139
#     140     def inverse_transform(self, y):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_encode.py in _encode(values, uniques, check_unknown)
#     181     else:
# ...

# %%
list(le.classes_)
# list(le.inverse_transform([0, 1, 2]))
# Out:
# ['C', 'Q', 'S']

# %%
## Data understanding/inspection

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Embarked
# count  891.000000  891.000000
# mean    32.204208    1.536476
# std     49.693429    0.791503
# min      0.000000    0.000000
# 25%      7.910400    1.000000
# 50%     14.454200    2.000000
# 75%     31.000000    2.000000
# max    512.329200    2.000000

# %%
# PassangerID is not relevent.

# %%
df [(df['Age']<10) ].head(30)
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 7            382      Yes       3               Nakid, Miss. Maria ("Mary")
# 39            44      Yes       2  Laroche, Miss. Simonne Marie Anne Andree
# 47            51       No       3                Panula, Master. Juha Niilo
# 64           279       No       3                        Rice, Master. Eric
# 82           756      Yes       2                 Hamalainen, Master. Viljo
# 102          825       No       3              Panula, Master. Urho Abraham
# 111          349      Yes       3    Coutts, Master. William Loch "William"
# 153          643       No       3             Skoog, Miss. Margit Elizabeth
# 158           17       No       3                      Rice, Master. Eugene
# 165          183       No       3     Asplund, Master. Clarence Gustaf Hugo
# 166          173      Yes       3              Johnson, Miss. Eleanor Ileen
# ...

# %%
df [(df['Age']<10) & (df["Survived"] == 'Yes') ]
# Out:
#      PassengerId Survived  Pclass  \
# 7            382      Yes       3
# 39            44      Yes       2
# 82           756      Yes       2
# 111          349      Yes       3
# 166          173      Yes       3
# 188          408      Yes       2
# 193          751      Yes       2
# 194          531      Yes       2
# 215          490      Yes       3
# 226          536      Yes       2
# 228           11      Yes       3
# 257          870      Yes       3
# 268          721      Yes       2
# 299          446      Yes       1
# 360          341      Yes       2
# 376           59      Yes       2
# 384          789      Yes       3
# 413          550      Yes       2
# 426          194      Yes       2
# 482          645      Yes       3
# 486          449      Yes       3
# 510          262      Yes       3
# 525          480      Yes       3
# 577          238      Yes       2
# 583          832      Yes       2
# 585           79      Yes       2
# ...

# %%
df [(df['Age']<10) & (df["Survived"] == 'No') ]
df [(df['Age']<10) & (df["Survived"] == 'No') ].sum()
# Out:
# PassengerId                                                 8930
# Survived        NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# Pclass                                                        70
# Name           Panula, Master. Juha NiiloRice, Master. EricPa...
# Sex            malemalemalefemalemalemalefemalemalefemalefema...
# Age                                                        121.0
# SibSp                                                         80
# Parch                                                         36
# Ticket         3101295382652310129534708838265234707734708834...
# Fare                                                    844.4083
# Embarked                                                      42
# dtype: object

# %%
df [ (df['Cabin'] == "NaN")]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
## Cleanining

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Cabin'].dropna().value_counts()
# Out:
# B96 B98        4
# C23 C25 C27    4
# G6             4
# F2             3
# F33            3
#               ..
# B39            1
# B86            1
# C104           1
# C86            1
# D11            1
# Name: Cabin, Length: 147, dtype: int64

# %%
df[df['Cabin']== 'G6']
# Out:
#      PassengerId Survived  Pclass  \
# 228           11      Yes       3
# 320          395      Yes       3
# 813          252       No       3
# 860          206       No       3
#
#                                                   Name     Sex   Age  SibSp  \
# 228                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 320  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 813         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# 860                         Strom, Miss. Telma Matilda  female   2.0      0
#
#      Parch   Ticket     Fare Cabin  Embarked
# 228      1  PP 9549  16.7000    G6         2
# 320      2  PP 9549  16.7000    G6         2
# 813      1   347054  10.4625    G6         2
# 860      1   347054  10.4625    G6         2

# %%
def search_by_name(text):
    if text:
        if 'Sandstorm' in text: 
            return True 
        else: 
            return False
    
df[df['Name'].map(search_by_name)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Ticket'].map(lambda text: 'PP 9549' in text)]
# Out:
#      PassengerId Survived  Pclass  \
# 228           11      Yes       3
# 320          395      Yes       3
#
#                                                   Name     Sex   Age  SibSp  \
# 228                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 320  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
#
#      Parch   Ticket  Fare Cabin  Embarked
# 228      1  PP 9549  16.7    G6         2
# 320      2  PP 9549  16.7    G6         2

# %%
df.drop('Cabin', axis=1, inplace=True)

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ...

# %%
# Drop colums

# %%
df.drop('PassengerId', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    int32
# dtypes: float64(2), int32(1), int64(3), object(4)
# memory usage: 66.3+ KB

# %%
cleanup_nums = {"Sex": {"male" : 1, "female": 2}}
df.replace(cleanup_nums, inplace=True)
df.head()
# Out:
#   Survived  Pclass                                         Name  Sex   Age  \
# 0       No       2                   Collander, Mr. Erik Gustaf    1  28.0
# 1       No       3                      Moen, Mr. Sigurd Hansen    1  25.0
# 2       No       3                       Jensen, Mr. Hans Peder    1  20.0
# 3       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)    2  29.0
# 4       No       1                       Davidson, Mr. Thornton    1  31.0
#
#    SibSp  Parch      Ticket     Fare  Embarked
# 0      0      0      248740  13.0000         2
# 1      0      0      348123   7.6500         2
# 2      0      0      350050   7.8542         2
# 3      0      4      349909  21.0750         2
# 4      1      0  F.C. 12750  52.0000         2

# %%
#df.replace({'Sex':{'male': 0, 'female':2})

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit_transform(df['Sex'])
le.(df)
# Out:
#   File "<ipython-input-26-b7ab6bea9e61>", line 5
#     le.(df)
#        ^
# SyntaxError: invalid syntax

# %%
X = df['Age']
Y = df['Sex']
correlation = np.corrcoef(X, Y)
print(Y)
print(X)
print(correlation)
plt.scatter(Y, X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-650011e30847> in <module>
#       1 X = df['Age']
#       2 Y = df['Sex']
# ----> 3 correlation = np.corrcoef(X, Y)
#       4 print(Y)
#       5 print(X)
#
# NameError: name 'np' is not defined

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(X, Y)
plt.show()

# %%
cleanup_num = {"Survived": {"Yes" : 1, "No": 0}}
df.replace(cleanup_num, inplace=True)
df.head()
# Out:
#    Survived  Pclass                                         Name  Sex   Age  \
# 0         0       2                   Collander, Mr. Erik Gustaf    1  28.0
# 1         0       3                      Moen, Mr. Sigurd Hansen    1  25.0
# 2         0       3                       Jensen, Mr. Hans Peder    1  20.0
# 3         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)    2  29.0
# 4         0       1                       Davidson, Mr. Thornton    1  31.0
#
#    SibSp  Parch      Ticket     Fare  Embarked
# 0      0      0      248740  13.0000         2
# 1      0      0      348123   7.6500         2
# 2      0      0      350050   7.8542         2
# 3      0      4      349909  21.0750         2
# 4      1      0  F.C. 12750  52.0000         2

# %%
import numpy as np 
Z = df[(df['Survived']==1) ]
print(Z)
X = Z['Age']
Y = Z['Sex']
correlation = np.corrcoef(X, Y)
print(Y)
print(X)
print(correlation)
plt.scatter(Y, X)
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 7           1       3                        Nakid, Miss. Maria ("Mary")    2
# 9           1       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...    2
# 12          1       2                   Herman, Mrs. Samuel (Jane Laver)    2
# 19          1       1                       Hoyt, Mr. Frederick Maxfield    1
# 20          1       3                     McDermott, Miss. Brigdet Delia    2
# ..        ...     ...                                                ...  ...
# 879         1       3                         Healy, Miss. Hanora "Nora"    2
# 880         1       3                  Mockler, Miss. Helen Mary "Ellie"    2
# 882         1       2              Hocking, Mrs. Elizabeth (Eliza Needs)    2
# 886         1       2                Nasser, Mrs. Nicholas (Adele Achem)    2
# 890         1       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    2
#
# ...

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df)

# %%
df[["Pclass", "Survived"]].groupby(["Pclass"], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
correl= np.corrcoef(df["Age"],df["Sex"],["Fare"])
print(correl)
df.head()
# Out:
# [[nan nan]
#  [nan  1.]]
#    Survived  Pclass                                         Name  Sex   Age  \
# 0         0       2                   Collander, Mr. Erik Gustaf    1  28.0
# 1         0       3                      Moen, Mr. Sigurd Hansen    1  25.0
# 2         0       3                       Jensen, Mr. Hans Peder    1  20.0
# 3         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)    2  29.0
# 4         0       1                       Davidson, Mr. Thornton    1  31.0
#
#    SibSp  Parch      Ticket     Fare  Embarked
# 0      0      0      248740  13.0000         2
# 1      0      0      348123   7.6500         2
# 2      0      0      350050   7.8542         2
# 3      0      4      349909  21.0750         2
# 4      1      0  F.C. 12750  52.0000         2

# %%
def Title_Dictionary(df) : {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                   "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess" : "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs" , 

                    "Master" :    "Master"

                    }


df[df['Name'].map(lambda text: Title_Dictionary(df) in text)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d326a06c25e9> in <module>
#      40
#      41
# ---> 42 df[df['Name'].map(lambda text: Title_Dictionary(df) in text)]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3907         dtype: object
#    3908         """
# -> 3909         new_values = super()._map_values(arg, na_action=na_action)
#    3910         return self._constructor(new_values, index=self.index).__finalize__(
#    3911             self, method="map"
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     935
#     936         # mapper is a function
# --> 937         new_values = map_f(values, mapper)
#     938
#     939         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-34-d326a06c25e9> in <lambda>(text)
# ...

# %%
L = df[(df['Name']=="Mr")]
print(L)
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
df[df['Name'].map(lambda text: 'Mr.' in text)]
# Out:
#      Survived  Pclass                              Name  Sex   Age  SibSp  \
# 0           0       2        Collander, Mr. Erik Gustaf    1  28.0      0
# 1           0       3           Moen, Mr. Sigurd Hansen    1  25.0      0
# 2           0       3            Jensen, Mr. Hans Peder    1  20.0      0
# 4           0       1            Davidson, Mr. Thornton    1  31.0      1
# 5           0       3    Gustafsson, Mr. Anders Vilhelm    1  37.0      2
# ..        ...     ...                               ...  ...   ...    ...
# 881         0       1          Thayer, Mr. John Borland    1  49.0      1
# 883         0       2                 Meyer, Mr. August    1  39.0      0
# 884         0       2       Parkes, Mr. Francis "Frank"    1   NaN      0
# 887         0       3             Sirayanian, Mr. Orsen    1  22.0      0
# 889         0       3  Petroff, Mr. Pastcho ("Pentcho")    1   NaN      0
#
#      Parch      Ticket      Fare  Embarked
# ...

# %%
df[df['Name'].map(lambda text: 'Ms.' in text)]
# Out:
#      Survived  Pclass                       Name  Sex   Age  SibSp  Parch  \
# 820         1       2  Reynaldo, Ms. Encarnacion    2  28.0      0      0
#
#      Ticket  Fare  Embarked
# 820  230434  13.0         2
